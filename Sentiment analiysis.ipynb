# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('youtoxic_english_1000.csv')

# %%
df
# Out:
#                 CommentId      VideoId  \
# 0    Ugg2KwwX0V8-aXgCoAEC  04kJtp6pVXI
# 1    Ugg2s5AzSPioEXgCoAEC  04kJtp6pVXI
# 2    Ugg3dWTOxryFfHgCoAEC  04kJtp6pVXI
# 3    Ugg7Gd006w1MPngCoAEC  04kJtp6pVXI
# 4    Ugg8FfTbbNF8IngCoAEC  04kJtp6pVXI
# ..                    ...          ...
# 995  Ugi5ADt10EdDz3gCoAEC  XRuCW80L9mA
# 996  Ugifh2DMhBbDkHgCoAEC  XRuCW80L9mA
# 997  Ugj_plbGBjjzYXgCoAEC  XRuCW80L9mA
# 998  Ugj0bah1De8xy3gCoAEC  XRuCW80L9mA
# 999  UgjBJKQSoQMQ6ngCoAEC  XRuCW80L9mA
#
#                                                   Text  IsToxic  IsAbusive  \
# 0    If only people would just take a step back and...    False      False
# 1    Law enforcement is not trained to shoot to app...     True       True
# 2    \nDont you reckon them 'black lives matter' ba...     True       True
# 3    There are a very large number of people who do...    False      False
# 4    The Arab dude is absolutely right, he should h...    False      False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CommentId        1000 non-null   object
#  1   VideoId          1000 non-null   object
#  2   Text             1000 non-null   object
#  3   IsToxic          1000 non-null   bool
#  4   IsAbusive        1000 non-null   bool
#  5   IsThreat         1000 non-null   bool
#  6   IsProvocative    1000 non-null   bool
#  7   IsObscene        1000 non-null   bool
#  8   IsHatespeech     1000 non-null   bool
#  9   IsRacist         1000 non-null   bool
#  10  IsNationalist    1000 non-null   bool
#  11  IsSexist         1000 non-null   bool
#  12  IsHomophobic     1000 non-null   bool
#  13  IsReligiousHate  1000 non-null   bool
#  14  IsRadicalism     1000 non-null   bool
# dtypes: bool(12), object(3)
# memory usage: 35.3+ KB

# %%
df.describe()
# Out:
#                    CommentId      VideoId           Text IsToxic IsAbusive  \
# count                   1000         1000           1000    1000      1000
# unique                  1000           13            997       2         2
# top     Ugg2KwwX0V8-aXgCoAEC  9pr1oE34bIM  run them over   False     False
# freq                       1          274              3     538       647
#
#        IsThreat IsProvocative IsObscene IsHatespeech IsRacist IsNationalist  \
# count      1000          1000      1000         1000     1000          1000
# unique        2             2         2            2        2             2
# top       False         False     False        False    False         False
# freq        979           839       900          862      875           992
#
#        IsSexist IsHomophobic IsReligiousHate IsRadicalism
# count      1000         1000            1000         1000
# unique        2            1               2            1
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_IsToxic = LabelEncoder()

# %%
df['IsToxic_'] = le_IsToxic.fit_transform(df['IsToxic'])

# %%
df['IsAbusive_'] = le_IsToxic.fit_transform(df['IsAbusive'])

# %%
df['IsThreat_'] = le_IsToxic.fit_transform(df['IsThreat'])

# %%
df['IsObscene_'] = le_IsToxic.fit_transform(df['IsObscene'])

# %%
df['IsHatespeech_'] = le_IsToxic.fit_transform(df['IsHatespeech'])

# %%
df['IsRacist_'] = le_IsToxic.fit_transform(df['IsRacist'])

# %%
df['IsNationalist_'] = le_IsToxic.fit_transform(df['IsNationalist'])

# %%
df['IsSexist_'] = le_IsToxic.fit_transform(df['IsSexist'])

# %%
df['IsHomophobic_'] = le_IsToxic.fit_transform(df['IsHomophobic'])

# %%
df['IsReligiousHate_'] = le_IsToxic.fit_transform(df['IsReligiousHate'])

# %%
df['IsRadicalism_'] = le_IsToxic.fit_transform(df['IsRadicalism'])

# %%
df['IsProvocative_'] = le_IsToxic.fit_transform(df['IsProvocative'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CommentId         1000 non-null   object
#  1   VideoId           1000 non-null   object
#  2   Text              1000 non-null   object
#  3   IsToxic           1000 non-null   bool
#  4   IsAbusive         1000 non-null   bool
#  5   IsThreat          1000 non-null   bool
#  6   IsProvocative     1000 non-null   bool
#  7   IsObscene         1000 non-null   bool
#  8   IsHatespeech      1000 non-null   bool
#  9   IsRacist          1000 non-null   bool
#  10  IsNationalist     1000 non-null   bool
#  11  IsSexist          1000 non-null   bool
#  12  IsHomophobic      1000 non-null   bool
#  13  IsReligiousHate   1000 non-null   bool
#  14  IsRadicalism      1000 non-null   bool
#  15  IsToxic_          1000 non-null   int64
#  16  IsAbusive_        1000 non-null   int64
# ...

# %%
df.drop('IsToxic', axis = 1 , inplace = True)

# %%
df.drop('IsRacist', axis = 1 , inplace = True)

# %%
df.drop('IsAbusive', axis = 1 , inplace=True)

# %%
df.drop('IsThreat', axis = 1 , inplace=True)

# %%
df.drop('IsObscene', axis = 1 , inplace=True)

# %%
df.drop('IsHatespeech', axis = 1 , inplace=True)

# %%
df.drop('IsNationalist', axis = 1 , inplace=True)

# %%
df.drop('IsSexist', axis = 1 , inplace=True)

# %%
df.drop('IsHomophobic',axis=1, inplace = True)

# %%
df.drop('IsReligiousHate',axis = 1 , inplace=True)

# %%
df.drop('IsRadicalism',axis = 1 , inplace=True)

# %%
df.drop('IsProvocative', axis = 1 , inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CommentId         1000 non-null   object
#  1   VideoId           1000 non-null   object
#  2   Text              1000 non-null   object
#  3   IsToxic_          1000 non-null   int64
#  4   IsAbusive_        1000 non-null   int64
#  5   IsThreat_         1000 non-null   int64
#  6   IsObscene_        1000 non-null   int64
#  7   IsHatespeech_     1000 non-null   int64
#  8   IsRacist_         1000 non-null   int64
#  9   IsNationalist_    1000 non-null   int64
#  10  IsSexist_         1000 non-null   int64
#  11  IsHomophobic_     1000 non-null   int64
#  12  IsReligiousHate_  1000 non-null   int64
#  13  IsRadicalism_     1000 non-null   int64
#  14  IsProvocative_    1000 non-null   int64
# dtypes: int64(12), object(3)
# memory usage: 117.3+ KB

# %%
df.drop('CommentId', axis = 1 , inplace=True)

# %%
df.drop('VideoId', axis = 1 , inplace=True)

# %%
for i in enumerate(df['Text'][:5]):
    print (i)
# Out:
# (0, "If only people would just take a step back and not make this case about them, because it wasn't about anyone except the two people in that situation.\xa0 To lump yourself into this mess and take matters into your own hands makes these kinds of protests selfish and without rational thought and investigation.\xa0 The guy in this video is heavily emotional and hyped up and wants to be heard, and when he gets heard he just presses more and more.\xa0 He was never out to have a reasonable discussion.\xa0 Kudos to the Smerconish for keeping level the whole time and letting Masri make himself out to be a fool.\xa0 How dare he and those that tore that city down in protest make this about themselves and to dishonor the entire incident with their own hate.\xa0 By the way, since when did police brutality become an epidemic?\xa0 I wish everyone would just stop pretending like they were there and they knew EXACTLY what was going on, because there's no measurable amount of people that honestly
# ...

# %%
df['Text'].apply(lambda x: len(x) if x!= {} else 0).value_counts().head()
# Out:
# 40    15
# 27    12
# 44    11
# 18    10
# 21     9
# Name: Text, dtype: int64

# %%
listoftext = list(df['Text'])

# %%
listoftext
# Out:
# ["If only people would just take a step back and not make this case about them, because it wasn't about anyone except the two people in that situation.\xa0 To lump yourself into this mess and take matters into your own hands makes these kinds of protests selfish and without rational thought and investigation.\xa0 The guy in this video is heavily emotional and hyped up and wants to be heard, and when he gets heard he just presses more and more.\xa0 He was never out to have a reasonable discussion.\xa0 Kudos to the Smerconish for keeping level the whole time and letting Masri make himself out to be a fool.\xa0 How dare he and those that tore that city down in protest make this about themselves and to dishonor the entire incident with their own hate.\xa0 By the way, since when did police brutality become an epidemic?\xa0 I wish everyone would just stop pretending like they were there and they knew EXACTLY what was going on, because there's no measurable amount of people that honestly wi
# ...

# %%
pip install wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
plt.figure(figsize = (12, 8))
text = ' '.join([i for j in listoftext for i in j])
wordcloud = WordCloud(max_font_size=None, background_color='white', collocations=False,
                      width=1200, height=1000).generate(text)
plt.imshow(wordcloud)

# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df.drop('Text', axis = 1 , inplace=True)

# %%
train =df.drop('IsToxic_', axis = 1)
test = df['IsToxic_']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(train, test, test_size = 0.19, random_state = 20)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg = LogisticRegression()

# %%
logreg.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
logreg.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
prediction = logreg.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, prediction)
# Out:
# 1.0
