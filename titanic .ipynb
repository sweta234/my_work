# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('rain.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
mean_age = df['Age'].mean()
df['Age_mean'] = df['Age'].fillna(mean_age)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  Age_mean     891 non-null    float64
# dtypes: float64(3), int64(5), object(5)
# memory usage: 90.6+ KB

# %%
df.drop('Age', axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    object
#  8   Fare         891 non-null    float64
#  9   Cabin        204 non-null    object
#  10  Embarked     889 non-null    object
#  11  Age_mean     891 non-null    float64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass     SibSp     Parch      Fare  \
# PassengerId     1.000000 -0.005007 -0.035144 -0.057527 -0.001652  0.012658
# Survived       -0.005007  1.000000 -0.338481 -0.035322  0.081629  0.257307
# Pclass         -0.035144 -0.338481  1.000000  0.083081  0.018443 -0.549500
# SibSp          -0.057527 -0.035322  0.083081  1.000000  0.414838  0.159651
# Parch          -0.001652  0.081629  0.018443  0.414838  1.000000  0.216225
# Fare            0.012658  0.257307 -0.549500  0.159651  0.216225  1.000000
# Age_mean        0.033207 -0.069809 -0.331339 -0.232625 -0.179191  0.091566
#
#              Age_mean
# PassengerId  0.033207
# Survived    -0.069809
# Pclass      -0.331339
# SibSp       -0.232625
# Parch       -0.179191
# Fare         0.091566
# Age_mean     1.000000

# %%
df.drop('Cabin', axis = 1 ,inplace = True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df.drop('Ticket', axis = 1, inplace=True)

# %%
df.drop('Name', axis = 1 , inplace = True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass     Sex  SibSp  Parch     Fare Embarked  \
# 0              1         0       3    male      1      0   7.2500        S
# 1              2         1       1  female      1      0  71.2833        C
# 2              3         1       3  female      0      0   7.9250        S
# 3              4         1       1  female      1      0  53.1000        S
# 4              5         0       3    male      0      0   8.0500        S
# ..           ...       ...     ...     ...    ...    ...      ...      ...
# 886          887         0       2    male      0      0  13.0000        S
# 887          888         1       1  female      0      0  30.0000        S
# 888          889         0       3  female      1      2  23.4500        S
# 889          890         1       1    male      0      0  30.0000        C
# 890          891         0       3    male      0      0   7.7500        Q
#
#       Age_mean
# 0    22.000000
# 1    38.000000
# 2    26.000000
# ...

# %%
df1 = pd.get_dummies(df)

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch     Fare   Age_mean  \
# 0              1         0       3      1      0   7.2500  22.000000
# 1              2         1       1      1      0  71.2833  38.000000
# 2              3         1       3      0      0   7.9250  26.000000
# 3              4         1       1      1      0  53.1000  35.000000
# 4              5         0       3      0      0   8.0500  35.000000
# ..           ...       ...     ...    ...    ...      ...        ...
# 886          887         0       2      0      0  13.0000  27.000000
# 887          888         1       1      0      0  30.0000  19.000000
# 888          889         0       3      1      2  23.4500  29.699118
# 889          890         1       1      0      0  30.0000  26.000000
# 890          891         0       3      0      0   7.7500  32.000000
#
#      Sex_female  Sex_male  Embarked_C  Embarked_Q  Embarked_S
# 0             0         1           0           0           1
# ...

# %%
test = pd.read_csv('test.csv')

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
test.drop('Cabin', axis = 1, inplace = True)

# %%
test.drop('Ticket',axis = 1 , inplace = True)

# %%
test.drop('Name', axis = 1, inplace = True)

# %%
test1 = pd.get_dummies(test)

# %%
test1
# Out:
#      PassengerId  Pclass   Age  SibSp  Parch      Fare  Sex_female  Sex_male  \
# 0            892       3  34.5      0      0    7.8292           0         1
# 1            893       3  47.0      1      0    7.0000           1         0
# 2            894       2  62.0      0      0    9.6875           0         1
# 3            895       3  27.0      0      0    8.6625           0         1
# 4            896       3  22.0      1      1   12.2875           1         0
# ..           ...     ...   ...    ...    ...       ...         ...       ...
# 413         1305       3   NaN      0      0    8.0500           0         1
# 414         1306       1  39.0      0      0  108.9000           1         0
# 415         1307       3  38.5      0      0    7.2500           0         1
# 416         1308       3   NaN      0      0    8.0500           0         1
# 417         1309       3   NaN      1      1   22.3583           0         1
#
#      Embarked_C  Embarked_Q  Embarked_S
# ...

# %%
mean_age = test1['Age'].mean()
test1['Age_mean'] = test1['Age'].fillna(mean_age)

# %%
test1
# Out:
#      PassengerId  Pclass   Age  SibSp  Parch      Fare  Sex_female  Sex_male  \
# 0            892       3  34.5      0      0    7.8292           0         1
# 1            893       3  47.0      1      0    7.0000           1         0
# 2            894       2  62.0      0      0    9.6875           0         1
# 3            895       3  27.0      0      0    8.6625           0         1
# 4            896       3  22.0      1      1   12.2875           1         0
# ..           ...     ...   ...    ...    ...       ...         ...       ...
# 413         1305       3   NaN      0      0    8.0500           0         1
# 414         1306       1  39.0      0      0  108.9000           1         0
# 415         1307       3  38.5      0      0    7.2500           0         1
# 416         1308       3   NaN      0      0    8.0500           0         1
# 417         1309       3   NaN      1      1   22.3583           0         1
#
# ...

# %%
test1
# Out:
#      PassengerId  Pclass   Age  SibSp  Parch      Fare  Sex_female  Sex_male  \
# 0            892       3  34.5      0      0    7.8292           0         1
# 1            893       3  47.0      1      0    7.0000           1         0
# 2            894       2  62.0      0      0    9.6875           0         1
# 3            895       3  27.0      0      0    8.6625           0         1
# 4            896       3  22.0      1      1   12.2875           1         0
# ..           ...     ...   ...    ...    ...       ...         ...       ...
# 413         1305       3   NaN      0      0    8.0500           0         1
# 414         1306       1  39.0      0      0  108.9000           1         0
# 415         1307       3  38.5      0      0    7.2500           0         1
# 416         1308       3   NaN      0      0    8.0500           0         1
# 417         1309       3   NaN      1      1   22.3583           0         1
#
# ...

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch     Fare   Age_mean  \
# 0              1         0       3      1      0   7.2500  22.000000
# 1              2         1       1      1      0  71.2833  38.000000
# 2              3         1       3      0      0   7.9250  26.000000
# 3              4         1       1      1      0  53.1000  35.000000
# 4              5         0       3      0      0   8.0500  35.000000
# ..           ...       ...     ...    ...    ...      ...        ...
# 886          887         0       2      0      0  13.0000  27.000000
# 887          888         1       1      0      0  30.0000  19.000000
# 888          889         0       3      1      2  23.4500  29.699118
# 889          890         1       1      0      0  30.0000  26.000000
# 890          891         0       3      0      0   7.7500  32.000000
#
#      Sex_female  Sex_male  Embarked_C  Embarked_Q  Embarked_S
# 0             0         1           0           0           1
# ...

# %%
test1.drop('Age', axis = 1 , inplace = True)

# %%
test1
# Out:
#      PassengerId  Pclass  SibSp  Parch      Fare  Sex_female  Sex_male  \
# 0            892       3      0      0    7.8292           0         1
# 1            893       3      1      0    7.0000           1         0
# 2            894       2      0      0    9.6875           0         1
# 3            895       3      0      0    8.6625           0         1
# 4            896       3      1      1   12.2875           1         0
# ..           ...     ...    ...    ...       ...         ...       ...
# 413         1305       3      0      0    8.0500           0         1
# 414         1306       1      0      0  108.9000           1         0
# 415         1307       3      0      0    7.2500           0         1
# 416         1308       3      0      0    8.0500           0         1
# 417         1309       3      1      1   22.3583           0         1
#
#      Embarked_C  Embarked_Q  Embarked_S  Age_mean
# 0             0           1           0  34.50000
# ...

# %%
train_target = df1['Survived']
train_feature = test1.drop('Survived',axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14504/2313804347.py in <module>
#       1 train_target = df1['Survived']
# ----> 2 train_feature = test1.drop('Survived',axis = 1)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(train, test, test_size = 0.19, random_state = 20)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg = LogisticRegression()

# %%
logreg.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14504/3286230058.py in <module>
# ----> 1 logreg.fit(x_train, y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1342             _dtype = [np.float64, np.float32]
#    1343
# -> 1344         X, y = self._validate_data(X, y, accept_sparse='csr', dtype=_dtype,
#    1345                                    order="C",
#    1346                                    accept_large_sparse=solver != 'liblinear')
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# ...

# %%
prediction = logreg.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14504/2555036714.py in <module>
# ----> 1 prediction = logreg.predict(x_test)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     307             Predicted class label per sample.
#     308         """
# --> 309         scores = self.decision_function(X)
#     310         if len(scores.shape) == 1:
#     311             indices = (scores > 0).astype(int)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in decision_function(self, X)
#     280             class would be predicted.
#     281         """
# --> 282         check_is_fitted(self)
#     283
#     284         X = check_array(X, accept_sparse='csr')
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
# ...

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, prediction)
# Out:
# 0.8470588235294118

# %%
prediction.shape
# Out:
# (170,)
