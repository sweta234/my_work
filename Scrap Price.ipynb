# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('scrap price.csv')

# %%
df
# Out:
#       ID  symboling                      name fueltypes aspiration  \
# 0      1          3        alfa-romero giulia       gas        std
# 1      2          3       alfa-romero stelvio       gas        std
# 2      3          1  alfa-romero Quadrifoglio       gas        std
# 3      4          2               audi 100 ls       gas        std
# 4      5          2                audi 100ls       gas        std
# ..   ...        ...                       ...       ...        ...
# 200  201         -1           volvo 145e (sw)       gas        std
# 201  202         -1               volvo 144ea       gas      turbo
# 202  203         -1               volvo 244dl       gas        std
# 203  204         -1                 volvo 246    diesel      turbo
# 204  205         -1               volvo 264gl       gas      turbo
#
#     doornumbers      carbody drivewheels enginelocation  wheelbase  ...  \
# 0           two  convertible         rwd          front       88.6  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   name              205 non-null    object
#  3   fueltypes         205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumbers       205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheels       205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df.corr()
# Out:
#                         ID  symboling  wheelbase  carlength  carwidth  \
# ID                1.000000  -0.151621   0.129729   0.170636  0.052387
# symboling        -0.151621   1.000000  -0.531954  -0.357612 -0.232919
# wheelbase         0.129729  -0.531954   1.000000   0.874587  0.795144
# carlength         0.170636  -0.357612   0.874587   1.000000  0.841118
# carwidth          0.052387  -0.232919   0.795144   0.841118  1.000000
# carheight         0.255960  -0.541038   0.589435   0.491029  0.279210
# curbweight        0.071962  -0.227691   0.776386   0.877728  0.867032
# enginesize       -0.033930  -0.105790   0.569329   0.683360  0.735433
# boreratio         0.260064  -0.130051   0.488750   0.606454  0.559150
# stroke           -0.160824  -0.008735   0.160959   0.129533  0.182942
# compressionratio  0.150276  -0.178515   0.249786   0.158414  0.181129
# horsepower       -0.015006   0.070873   0.353294   0.552623  0.640732
# ...

# %%
# some columns have low correlation with price so i drop it

# %%
df.drop(['ID'],axis = 1 , inplace = True)

# %%
df.drop(['symboling'],axis = 1 , inplace = True)

# %%
df.drop(['compressionratio'],axis=1,inplace = True)

# %%
df.drop(['peakrpm'],axis = 1 ,inplace = True)

# %%
df.drop(['citympg'],axis = 1 , inplace = True)

# %%
df.drop(['highwaympg'],axis = 1 , inplace = True)

# %%
df.drop(['aspiration'],axis = 1, inplace = True)

# %%
import seaborn as sns

# %%
sns.kdeplot(df['wheelbase'])
# Out:
# <AxesSubplot:xlabel='wheelbase', ylabel='Density'>

# %%
sns.kdeplot(df['enginesize'])
# Out:
# <AxesSubplot:xlabel='enginesize', ylabel='Density'>

# %%
sns.kdeplot(df['boreratio'])
# Out:
# <AxesSubplot:xlabel='boreratio', ylabel='Density'>

# %%
sns.kdeplot(df['stroke'])
# Out:
# <AxesSubplot:xlabel='stroke', ylabel='Density'>

# %%
sns.kdeplot(df['horsepower'])
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='Density'>

# %%
df1 =pd.get_dummies(df, columns = ['fueltypes','enginelocation','doornumbers','drivewheels'],drop_first=True)

# %%
df1.drop(['name'],axis = 1, inplace = True)

# %%
df1['carbody'].unique()
# Out:
# array(['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop'],
#       dtype=object)

# %%
df1['enginetype'].unique()
# Out:
# array(['dohc', 'ohcv', 'ohc', 'l', 'rotor', 'ohcf', 'dohcv'], dtype=object)

# %%
df1['cylindernumber'].unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
df1['fuelsystem'].unique()
# Out:
# array(['mpfi', '2bbl', 'mfi', '1bbl', 'spfi', '4bbl', 'idi', 'spdi'],
#       dtype=object)

# %%
#df1['carbody'] = df['carbody'].map({'convertible':5,'wagon':4,'sedan':3,'hatchback':2,'hardtop':1})

# %%
#df1['cylindernumber'] = df1['cylindernumber'].map({'four':4,'six':6,'five':5,'three':3,'twelve':12,'two':2,'eight':8})

# %%
from sklearn.preprocessing import LabelEncoder

# %%
labelencoder = LabelEncoder()

# %%
df1['enginetype'] = labelencoder.fit_transform(df1['enginetype'])

# %%
df1['fuelsystem'] = labelencoder.fit_transform(df1['fuelsystem'])

# %%
df1['carbody'] = labelencoder.fit_transform(df1['carbody'])

# %%
df1['cylindernumber'] = labelencoder.fit_transform(df1['cylindernumber'])

# %%
df1
# Out:
#      carbody  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0          0       88.6      168.8      64.1       48.8        2548
# 1          0       88.6      168.8      64.1       48.8        2548
# 2          2       94.5      171.2      65.5       52.4        2823
# 3          3       99.8      176.6      66.2       54.3        2337
# 4          3       99.4      176.6      66.4       54.3        2824
# ..       ...        ...        ...       ...        ...         ...
# 200        3      109.1      188.8      68.9       55.5        2952
# 201        3      109.1      188.8      68.8       55.5        3049
# 202        3      109.1      188.8      68.9       55.5        3012
# 203        3      109.1      188.8      68.9       55.5        3217
# 204        3      109.1      188.8      68.9       55.5        3062
#
#      enginetype  cylindernumber  enginesize  fuelsystem  boreratio  stroke  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   carbody              205 non-null    int32
#  1   wheelbase            205 non-null    float64
#  2   carlength            205 non-null    float64
#  3   carwidth             205 non-null    float64
#  4   carheight            205 non-null    float64
#  5   curbweight           205 non-null    int64
#  6   enginetype           205 non-null    int32
#  7   cylindernumber       205 non-null    int32
#  8   enginesize           205 non-null    int64
#  9   fuelsystem           205 non-null    int32
#  10  boreratio            205 non-null    float64
#  11  stroke               205 non-null    float64
#  12  horsepower           205 non-null    int64
#  13  price                205 non-null    float64
#  14  fueltypes_gas        205 non-null    uint8
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
train = df1.drop('price', axis = 1)
test = df1['price']

# %%
x_train, x_test, y_train, y_test = train_test_split(train, test, test_size = 0.19, random_state = 20)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg = LogisticRegression()

# %%
logreg.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9760/3286230058.py in <module>
# ----> 1 logreg.fit(x_train, y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1345                                    order="C",
#    1346                                    accept_large_sparse=solver != 'liblinear')
# -> 1347         check_classification_targets(y)
#    1348         self.classes_ = np.unique(y)
#    1349
#
# ~\anaconda3\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
#     181     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     182                       'multilabel-indicator', 'multilabel-sequences']:
# --> 183         raise ValueError("Unknown label type: %r" % y_type)
#     184
#     185
#
# ...
