# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('sales.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 41 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   index                      5000 non-null   int64
#  1   CustomerID                 5000 non-null   int64
#  2   TOTAL_ORDERS               5000 non-null   int64
#  3   REVENUE                    5000 non-null   float64
#  4   AVERAGE_ORDER_VALUE        5000 non-null   float64
#  5   CARRIAGE_REVENUE           5000 non-null   float64
#  6   AVERAGESHIPPING            5000 non-null   float64
#  7   FIRST_ORDER_DATE           5000 non-null   object
#  8   LATEST_ORDER_DATE          5000 non-null   object
#  9   AVGDAYSBETWEENORDERS       5000 non-null   float64
#  10  DAYSSINCELASTORDER         5000 non-null   int64
#  11  MONDAY_ORDERS              5000 non-null   int64
#  12  TUESDAY_ORDERS             5000 non-null   int64
# ...

# %%
df.head(5)
# Out:
#    index  CustomerID  TOTAL_ORDERS   REVENUE  AVERAGE_ORDER_VALUE  \
# 0      0        2354           124  11986.54                96.67
# 1      1        2361            82  11025.96               134.46
# 2      2        2415            43   7259.69               168.83
# 3      3        2427            44   6992.27               158.92
# 4      4        2456            55   6263.44               113.88
#
#    CARRIAGE_REVENUE  AVERAGESHIPPING FIRST_ORDER_DATE LATEST_ORDER_DATE  \
# 0            529.59             4.27       2016-12-30        2021-10-24
# 1             97.92             1.19       2018-03-31        2021-10-24
# 2            171.69             3.99       2017-11-30        2021-10-24
# 3             92.82             2.11       2019-04-09        2021-10-24
# 4            179.04             3.26       2020-10-23        2021-10-24
#
#    AVGDAYSBETWEENORDERS  ...  WEEK3_DAY16_DAY23_REVENUE  \
# 0                 14.19  ...                    2592.18
# ...

# %%
df.describe()
# Out:
#              index     CustomerID  TOTAL_ORDERS       REVENUE  \
# count  5000.000000    5000.000000    5000.00000   5000.000000
# mean   2499.500000   43041.227800      12.87040   1681.523840
# std    1443.520003   49949.848017      12.67988   1998.618678
# min       0.000000    2333.000000       1.00000     38.500000
# 25%    1249.750000    4019.500000       3.00000    315.097500
# 50%    2499.500000   16097.000000       8.00000    966.725000
# 75%    3749.250000   74223.500000      20.00000   2493.072500
# max    4999.000000  279492.000000     156.00000  34847.400000
#
#        AVERAGE_ORDER_VALUE  CARRIAGE_REVENUE  AVERAGESHIPPING  \
# count          5000.000000       5000.000000      5000.000000
# mean            136.537378         46.036376         3.592574
# std              91.651569         47.879226         2.021360
# min              10.680000          0.000000         0.000000
# 25%              83.025000          9.980000         2.500000
# ...

# %%
import seaborn as sns

# %%
plt.figure(figsize=(30,10))
sns.barplot(x='TOTAL_ORDERS' , y = 'REVENUE' , data = df)
# Out:
# <AxesSubplot:xlabel='TOTAL_ORDERS', ylabel='REVENUE'>

# %%
sns.barplot(x = 'MONDAY_ORDERS', y = 'MONDAY_REVENUE' , data = df)
# Out:
# <AxesSubplot:xlabel='MONDAY_ORDERS', ylabel='MONDAY_REVENUE'>

# %%
sns.barplot(x = 'TUESDAY_ORDERS', y = 'TUESDAY_REVENUE' , data = df)
# Out:
# <AxesSubplot:xlabel='TUESDAY_ORDERS', ylabel='TUESDAY_REVENUE'>

# %%
sns.distplot(df['TOTAL_ORDERS'])
# Out:
# C:\Users\win10\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='TOTAL_ORDERS', ylabel='Density'>

# %%
sns.displot(df['REVENUE'])

# %%
sns.boxplot(df['REVENUE'])
# Out:
# C:\Users\win10\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='REVENUE'>

# %%
df['REVENUE'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       11986.54
# 1       11025.96
# 2        7259.69
# 3        6992.27
# 4        6263.44
#           ...
# 4995      117.49
# 4996      117.49
# 4997      117.49
# 4998      117.49
# 4999       94.14
# Name: REVENUE, Length: 5000, dtype: float64>

# %%
sns.displot(df['CARRIAGE_REVENUE'])

# %%
df1 = df.corr()

# %%
df1
# Out:
#                               index  CustomerID  TOTAL_ORDERS   REVENUE  \
# index                      1.000000    0.361094     -0.174568 -0.129248
# CustomerID                 0.361094    1.000000     -0.608092 -0.556489
# TOTAL_ORDERS              -0.174568   -0.608092      1.000000  0.771996
# REVENUE                   -0.129248   -0.556489      0.771996  1.000000
# AVERAGE_ORDER_VALUE       -0.079043   -0.226023     -0.065208  0.366302
# CARRIAGE_REVENUE          -0.147118   -0.576043      0.875733  0.655447
# AVERAGESHIPPING            0.126459    0.025649     -0.007855 -0.048932
# AVGDAYSBETWEENORDERS       0.070367    0.279182     -0.311838 -0.257746
# DAYSSINCELASTORDER         0.967184    0.375343     -0.256272 -0.197782
# MONDAY_ORDERS             -0.134449   -0.470777      0.741049  0.590764
# TUESDAY_ORDERS            -0.129591   -0.473127      0.766660  0.624238
# WEDNESDAY_ORDERS          -0.127699   -0.471577      0.778020  0.603069
# ...

# %%
plt.figure(figsize=(30,30))

sns.heatmap(df1)
# Out:
# <AxesSubplot:>

# %%
# average revenue
df['MONDAY_REVENUE'].mean()
# Out:
# 215.20833599999625

# %%
data  = df[['MONDAY_ORDERS','TUESDAY_ORDERS','WEDNESDAY_ORDERS','THURSDAY_ORDERS','FRIDAY_ORDERS',
            'SATURDAY_ORDERS','SUNDAY_ORDERS','MONDAY_REVENUE','TUESDAY_REVENUE','WEDNESDAY_REVENUE','THURSDAY_REVENUE',
            'FRIDAY_REVENUE','SATURDAY_REVENUE','SUNDAY_REVENUE']]

# %%
data.head(5)
# Out:
#    MONDAY_ORDERS  TUESDAY_ORDERS  WEDNESDAY_ORDERS  THURSDAY_ORDERS  \
# 0             13              13                29               25
# 1             11              13                10               13
# 2              5               4                 3                5
# 3             10               8                 5                8
# 4              2               3                 8                8
#
#    FRIDAY_ORDERS  SATURDAY_ORDERS  SUNDAY_ORDERS  MONDAY_REVENUE  \
# 0             19               15             10         1287.50
# 1             14               10             11         1253.08
# 2              5                8             13          698.95
# 3              5                3              5         1753.95
# 4             12               10             12          150.98
#
#    TUESDAY_REVENUE  WEDNESDAY_REVENUE  THURSDAY_REVENUE  FRIDAY_REVENUE  \
# 0          1054.15            2842.52           2133.79         2051.94
# ...

# %%
plt.subplots(figsize =(20,10))

sns.pointplot(x='MONDAY_ORDERS',y='MONDAY_REVENUE',data=data,color='black',alpha=0.8)
sns.pointplot(x='TUESDAY_ORDERS',y='TUESDAY_REVENUE',data=data,color='#CC0000',alpha=0.8)
sns.pointplot(x='WEDNESDAY_ORDERS',y='WEDNESDAY_REVENUE',data=data,color='#3399FF',alpha=0.8)
sns.pointplot(x='THURSDAY_ORDERS',y='THURSDAY_REVENUE',data=data,color='#3399FF',alpha=0.8)
sns.pointplot(x='FRIDAY_ORDERS',y='FRIDAY_REVENUE',data=data,color='#3399FF',alpha=0.8)
sns.pointplot(x='SATURDAY_ORDERS',y='SATURDAY_REVENUE',data=data,color='#3399FF',alpha=0.8)
sns.pointplot(x='SUNDAY_ORDERS',y='SUNDAY_REVENUE',data=data,color='#3399FF',alpha=0.8)

plt.xlabel('ORDER',fontsize = 15,color='blue')
plt.ylabel('REVENUE',fontsize = 15,color='blue')
plt.title('Solo vs Duo vs Squad Kills',fontsize = 20,color='blue')
plt.grid()
plt.show()
