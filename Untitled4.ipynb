# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("client_data.csv")

# %%
df.head(5)
# Out:
#                                  id                     channel_sales  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1  d29c2c54acc38ff3c0614d0a653813dd                           MISSING
# 2  764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
# 3  bba03439a292a1e166f80264c16191cb  lmkebamcaaclubfxadlmueccxoimlema
# 4  149d57cf92fc41cf94415803a877cb4b                           MISSING
#
#    cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# 0         0         54946                0  15-06-2013  15-06-2016
# 1      4660             0                0  21-08-2009  30-08-2016
# 2       544             0                0  16-04-2010  16-04-2016
# 3      1584             0                0  30-03-2010  30-03-2016
# 4      4425             0              526  13-01-2010  07-03-2016
#
#   date_modif_prod date_renewal  forecast_cons_12m  ...  has_gas  imp_cons  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14606 entries, 0 to 14605
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              14606 non-null  object
#  1   channel_sales                   14606 non-null  object
#  2   cons_12m                        14606 non-null  int64
#  3   cons_gas_12m                    14606 non-null  int64
#  4   cons_last_month                 14606 non-null  int64
#  5   date_activ                      14606 non-null  object
#  6   date_end                        14606 non-null  object
#  7   date_modif_prod                 14606 non-null  object
#  8   date_renewal                    14606 non-null  object
#  9   forecast_cons_12m               14606 non-null  float64
#  10  forecast_cons_year              14606 non-null  int64
#  11  forecast_discount_energy        14606 non-null  int64
# ...

# %%
df.corr()
# Out:
# C:\Users\win10\AppData\Local\Temp/ipykernel_3232/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                 cons_12m  cons_gas_12m  cons_last_month  \
# cons_12m                        1.000000      0.488474         0.968212
# cons_gas_12m                    0.488474      1.000000         0.507007
# cons_last_month                 0.968212      0.507007         1.000000
# forecast_cons_12m               0.193947      0.084359         0.177773
# forecast_cons_year              0.167093      0.080934         0.193574
# forecast_discount_energy       -0.043282     -0.012595        -0.040874
# forecast_meter_rent_12m         0.065268      0.041393         0.057476
# forecast_price_energy_off_peak -0.007748     -0.017684        -0.005187
# ...

# %%
numeric_data = df.select_dtypes('int64')

# %%
numeric_data
# Out:
#        cons_12m  cons_gas_12m  cons_last_month  forecast_cons_year  \
# 0             0         54946                0                   0
# 1          4660             0                0                   0
# 2           544             0                0                   0
# 3          1584             0                0                   0
# 4          4425             0              526                 526
# ...         ...           ...              ...                 ...
# 14601     32270         47940                0                   0
# 14602      7223             0              181                 181
# 14603      1844             0              179                 179
# 14604       131             0                0                   0
# 14605      8730             0                0                   0
#
#        forecast_discount_energy  nb_prod_act  num_years_antig  churn
# 0                             0            2                3      1
# ...

# %%
categorical_data = df.select_dtypes('object')

# %%
categorical_data
# Out:
#                                      id                     channel_sales  \
# 0      24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1      d29c2c54acc38ff3c0614d0a653813dd                           MISSING
# 2      764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
# 3      bba03439a292a1e166f80264c16191cb  lmkebamcaaclubfxadlmueccxoimlema
# 4      149d57cf92fc41cf94415803a877cb4b                           MISSING
# ...                                 ...                               ...
# 14601  18463073fb097fc0ac5d3e040f356987  foosdfpfkusacimwkcsosbicdxkicaua
# 14602  d0a6f71671571ed83b2645d23af6de00  foosdfpfkusacimwkcsosbicdxkicaua
# 14603  10e6828ddd62cbcf687cb74928c4c2d2  foosdfpfkusacimwkcsosbicdxkicaua
# 14604  1cf20fd6206d7678d5bcafd28c53b4db  foosdfpfkusacimwkcsosbicdxkicaua
# 14605  563dde550fd624d7352f3de77c0cdfcd                           MISSING
#
#        date_activ    date_end date_modif_prod date_renewal has_gas  \
# ...

# %%
num_data = df.select_dtypes('float64')

# %%
num_data
# Out:
#        forecast_cons_12m  forecast_meter_rent_12m  \
# 0                   0.00                     1.78
# 1                 189.95                    16.27
# 2                  47.96                    38.72
# 3                 240.04                    19.83
# 4                 445.75                   131.73
# ...                  ...                      ...
# 14601            4648.01                    18.57
# 14602             631.69                   144.03
# 14603             190.39                   129.60
# 14604              19.34                     7.18
# 14605             762.41                     1.07
#
#        forecast_price_energy_off_peak  forecast_price_energy_peak  \
# 0                            0.114481                    0.098142
# 1                            0.145711                    0.000000
# 2                            0.165794                    0.087899
# 3                            0.146694                    0.000000
# ...

# %%
categorical_data.drop(['id','channel_sales'], axis =  1, inplace= True)

# %%
categorical_data.drop(['origin_up'], axis =  1, inplace= True)

# %%
categorical_data
# Out:
#        date_activ    date_end date_modif_prod date_renewal has_gas
# 0      15-06-2013  15-06-2016      01-11-2015   23-06-2015       t
# 1      21-08-2009  30-08-2016      21-08-2009   31-08-2015       f
# 2      16-04-2010  16-04-2016      16-04-2010   17-04-2015       f
# 3      30-03-2010  30-03-2016      30-03-2010   31-03-2015       f
# 4      13-01-2010  07-03-2016      13-01-2010   09-03-2015       f
# ...           ...         ...             ...          ...     ...
# 14601  24-05-2012  08-05-2016      08-05-2015   26-05-2014       t
# 14602  27-08-2012  27-08-2016      27-08-2012   28-08-2015       f
# 14603  08-02-2012  07-02-2016      08-02-2012   09-02-2015       f
# 14604  30-08-2012  30-08-2016      30-08-2012   31-08-2015       f
# 14605  18-12-2009  17-12-2016      18-12-2009   21-12-2015       f
#
# [14606 rows x 5 columns]

# %%
import datetime as dt

categorical_data['year_start_contract'] = pd.DatetimeIndex(categorical_data['date_activ']).year
categorical_data['year_end_contract'] = pd.DatetimeIndex(categorical_data['date_end']).year
# Out:
# C:\Users\win10\AppData\Local\Temp/ipykernel_3232/3183971263.py:3: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   categorical_data['year_start_contract'] = pd.DatetimeIndex(categorical_data['date_activ']).year
# C:\Users\win10\AppData\Local\Temp/ipykernel_3232/3183971263.py:4: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   categorical_data['year_end_contract'] = pd.DatetimeIndex(categorical_data['date_end']).year

# %%
categorical_data
# Out:
#        date_activ    date_end date_modif_prod date_renewal has_gas  \
# 0      15-06-2013  15-06-2016      01-11-2015   23-06-2015       t
# 1      21-08-2009  30-08-2016      21-08-2009   31-08-2015       f
# 2      16-04-2010  16-04-2016      16-04-2010   17-04-2015       f
# 3      30-03-2010  30-03-2016      30-03-2010   31-03-2015       f
# 4      13-01-2010  07-03-2016      13-01-2010   09-03-2015       f
# ...           ...         ...             ...          ...     ...
# 14601  24-05-2012  08-05-2016      08-05-2015   26-05-2014       t
# 14602  27-08-2012  27-08-2016      27-08-2012   28-08-2015       f
# 14603  08-02-2012  07-02-2016      08-02-2012   09-02-2015       f
# 14604  30-08-2012  30-08-2016      30-08-2012   31-08-2015       f
# 14605  18-12-2009  17-12-2016      18-12-2009   21-12-2015       f
#
#        year_start_contract  year_end_contract
# 0                     2013               2016
# 1                     2009               2016
# ...

# %%
categorical_data['contract_period_in year'] = categorical_data['year_end_contract'] - categorical_data['year_start_contract']

# %%
categorical_data.drop(['date_activ','date_end','date_modif_prod','date_renewal'], axis =  1, inplace= True)

# %%
categorical_data
# Out:
#       has_gas  year_start_contract  year_end_contract  contract_period_in year
# 0           t                 2013               2016                        3
# 1           f                 2009               2016                        7
# 2           f                 2010               2016                        6
# 3           f                 2010               2016                        6
# 4           f                 2010               2016                        6
# ...       ...                  ...                ...                      ...
# 14601       t                 2012               2016                        4
# 14602       f                 2012               2016                        4
# 14603       f                 2012               2016                        4
# 14604       f                 2012               2016                        4
# 14605       f                 2009               2016                        7
#
# ...

# %%
res = pd.concat([numeric_data , num_data,categorical_data], axis = 1)

# %%
res.corr()
# Out:
# C:\Users\win10\AppData\Local\Temp/ipykernel_3232/1961073195.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   res.corr()
#                                 cons_12m  cons_gas_12m  cons_last_month  \
# cons_12m                        1.000000      0.488474         0.968212
# cons_gas_12m                    0.488474      1.000000         0.507007
# cons_last_month                 0.968212      0.507007         1.000000
# forecast_cons_year              0.167093      0.080934         0.193574
# forecast_discount_energy       -0.043282     -0.012595        -0.040874
# nb_prod_act                     0.154251      0.239387         0.169099
# num_years_antig                -0.003565     -0.013815        -0.003677
# churn                          -0.045968     -0.037957        -0.045284
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
res.head(5)
# Out:
#    cons_12m  cons_gas_12m  cons_last_month  forecast_cons_year  \
# 0         0         54946                0                   0
# 1      4660             0                0                   0
# 2       544             0                0                   0
# 3      1584             0                0                   0
# 4      4425             0              526                 526
#
#    forecast_discount_energy  nb_prod_act  num_years_antig  churn  \
# 0                         0            2                3      1
# 1                         0            1                6      0
# 2                         0            1                6      0
# 3                         0            1                6      0
# 4                         0            1                6      0
#
#    forecast_cons_12m  forecast_meter_rent_12m  ...  \
# 0               0.00                     1.78  ...
# 1             189.95                    16.27  ...
# ...

# %%
res.columns
# Out:
# Index(['cons_12m', 'cons_gas_12m', 'cons_last_month', 'forecast_cons_year',
#        'forecast_discount_energy', 'nb_prod_act', 'num_years_antig', 'churn',
#        'forecast_cons_12m', 'forecast_meter_rent_12m',
#        'forecast_price_energy_off_peak', 'forecast_price_energy_peak',
#        'forecast_price_pow_off_peak', 'imp_cons', 'margin_gross_pow_ele',
#        'margin_net_pow_ele', 'net_margin', 'pow_max', 'has_gas',
#        'year_start_contract', 'year_end_contract', 'contract_period_in year'],
#       dtype='object')

# %%
res['contract_period_in year'].value_counts().sort_values(ascending=False)
# Out:
# 4     3616
# 6     3413
# 7     2959
# 5     2903
# 3     1058
# 11     191
# 8      155
# 12     141
# 10      72
# 9       54
# 13      43
# 2        1
# Name: contract_period_in year, dtype: int64

# %%
sns.barplot(res['contract_period_in year'], res['cons_12m'])
# Out:
# C:\Users\win10\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='contract_period_in year', ylabel='cons_12m'>

# %%
res['has_gas'].value_counts().sort_values(ascending=False)
# Out:
# f    11955
# t     2651
# Name: has_gas, dtype: int64

# %%
# gas has 
X = res[res['has_gas'] == 'f']
sns.barplot(X['contract_period_in year'], X['cons_gas_12m'])
# Out:
# C:\Users\win10\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='contract_period_in year', ylabel='cons_gas_12m'>

# %%
sns.barplot(res['contract_period_in year'], res['forecast_cons_12m'])
# Out:
# C:\Users\win10\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='contract_period_in year', ylabel='forecast_cons_12m'>

# %%
sns.barplot(res['contract_period_in year'], res['forecast_meter_rent_12m'])
# Out:
# C:\Users\win10\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='contract_period_in year', ylabel='forecast_meter_rent_12m'>

# %%
sns.barplot(res['contract_period_in year'], res['margin_net_pow_ele'])
# Out:
# C:\Users\win10\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='contract_period_in year', ylabel='margin_net_pow_ele'>

# %%
(res['nb_prod_act'].value_counts())
# Out:
# 1     11431
# 2      2445
# 3       523
# 4       150
# 5        31
# 9        11
# 6         8
# 8         4
# 10        2
# 32        1
# Name: nb_prod_act, dtype: int64

# %%
sns.barplot(res['nb_prod_act'], res['cons_12m'])
# Out:
# C:\Users\win10\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='nb_prod_act', ylabel='cons_12m'>

# %%
sns.barplot(res['nb_prod_act'], res['net_margin'])
# Out:
# C:\Users\win10\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='nb_prod_act', ylabel='net_margin'>

# %%
res['num_years_antig'].value_counts()
# Out:
# 6     4769
# 4     3982
# 3     2433
# 5     2317
# 7      509
# 11     185
# 12     110
# 8      103
# 9       92
# 10      81
# 13      13
# 2       11
# 1        1
# Name: num_years_antig, dtype: int64

# %%
sns.barplot(res['num_years_antig'], res['cons_12m'])
# Out:
# C:\Users\win10\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='num_years_antig', ylabel='cons_12m'>

# %%
res['churn'].value_counts()
# Out:
# 0    13187
# 1     1419
# Name: churn, dtype: int64
