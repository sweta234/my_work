# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('onlinefraud.csv')

# %%
df
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# 1              19384.72  M2044282225            0.00            0.00        0
# 2                  0.00   C553264065            0.00            0.00        1
# 3                  0.00    C38997010        21182.00            0.00        1
# 4              29885.86  M1230701703            0.00            0.00        0
# ...                 ...          ...             ...             ...      ...
# 6362615            0.00   C776919290            0.00       339682.13        1
# 6362616            0.00  C1881841831            0.00            0.00        1
# 6362617            0.00  C1365125890        68488.84      6379898.11        1
# 6362618            0.00  C2080388513            0.00            0.00        1
# 6362619            0.00   C873221189      6510099.11      7360101.63        1
#
#          isFlaggedFraud
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 6362615               0
# 6362616               0
# 6362617               0
# 6362618               0
# 6362619               0
#
# [6362620 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %%
df['type'].value_counts()
# Out:
# CASH_OUT    2237500
# PAYMENT     2151495
# CASH_IN     1399284
# TRANSFER     532909
# DEBIT         41432
# Name: type, dtype: int64

# %%
df.describe()
# Out:
#                step        amount  oldbalanceOrg  newbalanceOrig  \
# count  6.362620e+06  6.362620e+06   6.362620e+06    6.362620e+06
# mean   2.433972e+02  1.798619e+05   8.338831e+05    8.551137e+05
# std    1.423320e+02  6.038582e+05   2.888243e+06    2.924049e+06
# min    1.000000e+00  0.000000e+00   0.000000e+00    0.000000e+00
# 25%    1.560000e+02  1.338957e+04   0.000000e+00    0.000000e+00
# 50%    2.390000e+02  7.487194e+04   1.420800e+04    0.000000e+00
# 75%    3.350000e+02  2.087215e+05   1.073152e+05    1.442584e+05
# max    7.430000e+02  9.244552e+07   5.958504e+07    4.958504e+07
#
#        oldbalanceDest  newbalanceDest       isFraud  isFlaggedFraud
# count    6.362620e+06    6.362620e+06  6.362620e+06    6.362620e+06
# mean     1.100702e+06    1.224996e+06  1.290820e-03    2.514687e-06
# std      3.399180e+06    3.674129e+06  3.590480e-02    1.585775e-03
# min      0.000000e+00    0.000000e+00  0.000000e+00    0.000000e+00
# 25%      0.000000e+00    0.000000e+00  0.000000e+00    0.000000e+00
# 50%      1.327057e+05    2.146614e+05  0.000000e+00    0.000000e+00
# 75%      9.430367e+05    1.111909e+06  0.000000e+00    0.000000e+00
# max      3.560159e+08    3.561793e+08  1.000000e+00    1.000000e+00

# %%
sns.scatterplot(x = 'oldbalanceOrg', y = 'newbalanceOrig' , data = df)
# Out:
# <AxesSubplot:xlabel='oldbalanceOrg', ylabel='newbalanceOrig'>

# %%
df['oldbalanceOrg'].value_counts()
# Out:
# 0.00         2102449
# 184.00           918
# 133.00           914
# 195.00           912
# 164.00           909
#               ...
# 34577.49           1
# 184929.21          1
# 29320.33           1
# 82645.19           1
# 641239.85          1
# Name: oldbalanceOrg, Length: 1845844, dtype: int64

# %%
df['newbalanceOrig'].value_counts()
# Out:
# 0.00         3609566
# 5888.64            4
# 15073.44           4
# 5122.00            4
# 36875.73           4
#               ...
# 51345.64           1
# 46527.23           1
# 30839.51           1
# 25521.75           1
# 160296.36          1
# Name: newbalanceOrig, Length: 2682586, dtype: int64

# %%
df['oldbalanceDest'].value_counts()
# Out:
# 0.00           2704388
# 10000000.00        615
# 20000000.00        219
# 30000000.00         86
# 40000000.00         31
#                 ...
# 967022.27            1
# 327279.67            1
# 2039554.04           1
# 587552.25            1
# 6510099.11           1
# Name: oldbalanceDest, Length: 3614697, dtype: int64

# %%
df['newbalanceDest'].value_counts()
# Out:
# 0.00           2439433
# 10000000.00         53
# 971418.91           32
# 19169204.93         29
# 1254956.07          25
#                 ...
# 188439.36            1
# 1347758.15           1
# 3878719.83           1
# 1605826.83           1
# 7360101.63           1
# Name: newbalanceDest, Length: 3555499, dtype: int64

# %%
df['isFraud'].value_counts()
# Out:
# 0    6354407
# 1       8213
# Name: isFraud, dtype: int64

# %%
d  = df[df['newbalanceOrig'] == 0]

# %%
d['isFlaggedFraud'].value_counts()
# Out:
# 0    3609566
# Name: isFlaggedFraud, dtype: int64

# %%
df[df['isFraud'] == 1]
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 251         1  TRANSFER     2806.00  C1420196421        2806.00
# 252         1  CASH_OUT     2806.00  C2101527076        2806.00
# 680         1  TRANSFER    20128.00   C137533655       20128.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 2                   0.0   C553264065            0.00            0.00        1
# 3                   0.0    C38997010        21182.00            0.00        1
# 251                 0.0   C972765878            0.00            0.00        1
# 252                 0.0  C1007251739        26202.00            0.00        1
# 680                 0.0  C1848415041            0.00            0.00        1
# ...                 ...          ...             ...             ...      ...
# 6362615             0.0   C776919290            0.00       339682.13        1
# 6362616             0.0  C1881841831            0.00            0.00        1
# 6362617             0.0  C1365125890        68488.84      6379898.11        1
# 6362618             0.0  C2080388513            0.00            0.00        1
# 6362619             0.0   C873221189      6510099.11      7360101.63        1
#
#          isFlaggedFraud
# 2                     0
# 3                     0
# 251                   0
# 252                   0
# 680                   0
# ...                 ...
# 6362615               0
# 6362616               0
# 6362617               0
# 6362618               0
# 6362619               0
#
# [8213 rows x 11 columns]

# %%
sns.barplot(df['type'],df['oldbalanceOrg'])
# Out:
# C:\Users\win10\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='type', ylabel='oldbalanceOrg'>

# %%
sns.countplot(x = 'type', data = df)
# Out:
# <AxesSubplot:xlabel='type', ylabel='count'>

# %%
sns.barplot(df['type'],df['newbalanceOrig'])
# Out:
# C:\Users\win10\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='type', ylabel='newbalanceOrig'>

# %%
df.head(1)
# Out:
#    step     type   amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1  PAYMENT  9839.64  C1231006815       170136.0       160296.36
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0

# %%
df.drop('nameOrig', axis = 1 ,inplace= True)
df.drop('nameDest', axis = 1 , inplace = True)
df.drop('isFlaggedFraud' , axis = 1 , inplace = True)

# %%
df['type'] = df['type'].map({'PAYMENT': 1, 'TRANSFER': 2 , 'CASH_OUT': 3 , 'DEBIT': 4,  'CASH_IN':5})

# %%
df.head(1)
# Out:
#    step  type   amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0     1     1  9839.64       170136.0       160296.36             0.0
#
#    newbalanceDest  isFraud
# 0             0.0        0

# %%
train = df.drop('isFraud',  axis = 1)
test = df['isFraud']

# %%
train
# Out:
#          step  type      amount  oldbalanceOrg  newbalanceOrig  \
# 0           1     1     9839.64      170136.00       160296.36
# 1           1     1     1864.28       21249.00        19384.72
# 2           1     2      181.00         181.00            0.00
# 3           1     3      181.00         181.00            0.00
# 4           1     1    11668.14       41554.00        29885.86
# ...       ...   ...         ...            ...             ...
# 6362615   743     3   339682.13      339682.13            0.00
# 6362616   743     2  6311409.28     6311409.28            0.00
# 6362617   743     3  6311409.28     6311409.28            0.00
# 6362618   743     2   850002.52      850002.52            0.00
# 6362619   743     3   850002.52      850002.52            0.00
#
#          oldbalanceDest  newbalanceDest
# 0                  0.00            0.00
# 1                  0.00            0.00
# 2                  0.00            0.00
# 3              21182.00            0.00
# 4                  0.00            0.00
# ...                 ...             ...
# 6362615            0.00       339682.13
# 6362616            0.00            0.00
# 6362617        68488.84      6379898.11
# 6362618            0.00            0.00
# 6362619      6510099.11      7360101.63
#
# [6362620 rows x 7 columns]

# %%
test
# Out:
# 0          0
# 1          0
# 2          1
# 3          1
# 4          0
#           ..
# 6362615    1
# 6362616    1
# 6362617    1
# 6362618    1
# 6362619    1
# Name: isFraud, Length: 6362620, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(train, test, test_size = 0.19, random_state = 20)

# %%
x_train
# Out:
#          step  type      amount  oldbalanceOrg  newbalanceOrig  \
# 4339402   308     3   293282.23           0.00            0.00
# 1865278   164     1    13846.40      466373.43       452527.03
# 169051     12     1     5855.01           0.00            0.00
# 4510639   325     3   298565.29       51809.00            0.00
# 1784323   162     1    11342.79       50428.00        39085.21
# ...       ...   ...         ...            ...             ...
# 3890076   284     5   295392.16     5611895.92      5907288.08
# 5528799   381     2  3274838.42           0.00            0.00
# 5280015   372     1    19945.41       11253.00            0.00
# 2976218   231     1    28077.14       13653.37            0.00
# 1031523    93     1     1290.10       38684.74        37394.65
#
#          oldbalanceDest  newbalanceDest
# 4339402      1257015.37      1550297.59
# 1865278            0.00            0.00
# 169051             0.00            0.00
# 4510639      8065318.99      8363884.28
# 1784323            0.00            0.00
# ...                 ...             ...
# 3890076       421265.30       125873.14
# 5528799      3953913.51      7228751.92
# 5280015            0.00            0.00
# 2976218            0.00            0.00
# 1031523            0.00            0.00
#
# [5153722 rows x 7 columns]

# %%
x_test
# Out:
#          step  type     amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 5693671   397     5   84576.12     1418366.78      1502942.90       394630.67
# 6189157   570     5   51074.99      171405.00       222479.99       678275.85
# 3863893   283     3   39100.33           0.00            0.00       252508.47
# 1806996   163     1    4047.11           0.00            0.00            0.00
# 403593     18     1   30300.43       64959.00        34658.57            0.00
# ...       ...   ...        ...            ...             ...             ...
# 1231669   133     2  451992.88           0.00            0.00      2329568.04
# 5597274   394     1   36897.86      223426.30       186528.44            0.00
# 3397667   255     1    2246.27       22424.00        20177.73            0.00
# 3048543   234     3   51057.35       17962.00            0.00       201774.56
# 490718     19     1    2227.01           0.00            0.00            0.00
#
#          newbalanceDest
# 5693671       310054.54
# 6189157       627200.86
# 3863893       291608.80
# 1806996            0.00
# 403593             0.00
# ...                 ...
# 1231669      4698571.47
# 5597274            0.00
# 3397667            0.00
# 3048543       252831.91
# 490718             0.00
#
# [1208898 rows x 7 columns]

# %%
y_train
# Out:
# 4339402    0
# 1865278    0
# 169051     0
# 4510639    0
# 1784323    0
#           ..
# 3890076    0
# 5528799    0
# 5280015    0
# 2976218    0
# 1031523    0
# Name: isFraud, Length: 5153722, dtype: int64

# %%
x_train
# Out:
#          step  type      amount  oldbalanceOrg  newbalanceOrig  \
# 4339402   308     3   293282.23           0.00            0.00
# 1865278   164     1    13846.40      466373.43       452527.03
# 169051     12     1     5855.01           0.00            0.00
# 4510639   325     3   298565.29       51809.00            0.00
# 1784323   162     1    11342.79       50428.00        39085.21
# ...       ...   ...         ...            ...             ...
# 3890076   284     5   295392.16     5611895.92      5907288.08
# 5528799   381     2  3274838.42           0.00            0.00
# 5280015   372     1    19945.41       11253.00            0.00
# 2976218   231     1    28077.14       13653.37            0.00
# 1031523    93     1     1290.10       38684.74        37394.65
#
#          oldbalanceDest  newbalanceDest
# 4339402      1257015.37      1550297.59
# 1865278            0.00            0.00
# 169051             0.00            0.00
# 4510639      8065318.99      8363884.28
# 1784323            0.00            0.00
# ...                 ...             ...
# 3890076       421265.30       125873.14
# 5528799      3953913.51      7228751.92
# 5280015            0.00            0.00
# 2976218            0.00            0.00
# 1031523            0.00            0.00
#
# [5153722 rows x 7 columns]

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression()
log.fit(x_train, y_train)

# %%
prediction = log.predict(x_test)
from sklearn.metrics import accuracy_score
accuracy_score(y_test, prediction)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8152/3556501555.py in <module>
# ----> 1 prediction = log.predict(x_test)
#       2 from sklearn.metrics import accuracy_score
#       3 accuracy_score(y_test, prediction)
#
# NameError: name 'log' is not defined
